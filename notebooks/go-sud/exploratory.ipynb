# %%
from GG_mthesis import *
import metpy
import metpy.calc as mpcalc
from metpy.cbook import get_test_data
from metpy.units import units
# %matplotlib inline

# %%
path = 'data/01_raw/go-sud/FABB_BeautempsBeaupre/DM_FABB_2004a_TSG.nc'

#open the dataset with the defined path
ds_orig = xr.open_dataset(path, decode_times=False)

# %%
ds_orig
# Out:
# <xarray.Dataset>
# Dimensions:              (DAYD: 55732, DAYD_EXT: 92, NCOEF_CAL: 7, NCOEF_LIN: 2, N1: 1)
# Coordinates:
#   * DAYD                 (DAYD) float64 1.974e+04 1.974e+04 ... 2.006e+04
#   * DAYD_EXT             (DAYD_EXT) float64 1.974e+04 1.974e+04 ... 2.006e+04
# Dimensions without coordinates: NCOEF_CAL, NCOEF_LIN, N1
# Data variables: (12/67)
#     REFERENCE_DATE_TIME  |S14 b'19500101000000'
#     DATE                 (DAYD) |S14 b'20040116000000' ... b'20041202235700'
#     DATE_EXT             (DAYD_EXT) |S14 b'20040115113500' ... b'20041202175827'
#     LATX                 (DAYD) float32 27.77 27.76 27.76 ... 42.15 42.16 42.17
#     LATX_EXT             (DAYD_EXT) float32 27.84 27.88 27.0 ... 37.19 40.93
#     LONX                 (DAYD) float32 34.36 34.36 34.35 ... -9.757 -9.757
#     ...                   ...
#     SSTP_EXT_TYPE        (DAYD_EXT) |S4 b'UNKN' b'UNKN' ... b'ARGO' b'ARGO'
# ...

# %%
date_time_0 = str(int((ds_orig['REFERENCE_DATE_TIME'].values)))
year_0 = int(date_time_0[:4])
month_0 = int(date_time_0[4:6])
day_0 = int(date_time_0[6:8])
hour_0 = int(date_time_0[8:10])
minute_0 = int(date_time_0[10:12])
second_0 = int(date_time_0[12:14])
date_ini = np.datetime64(datetime(year_0, month_0, day_0, hour_0, minute_0, second_0))

# %%
t_delta = [np.timedelta64(int(float((ds_orig['DAYD'][i].values))*24*3600*10**9),'ns') for i in range(len(ds_orig['DAYD']))]

# %%
time = date_ini + t_delta

# %%
ds_orig.to_dataframe()
