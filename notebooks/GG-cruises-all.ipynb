# %%
from GG_mthesis import *
import metpy
import metpy.calc as mpcalc
from metpy.cbook import get_test_data
from metpy.units import units
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\gian_\\repos\\mthesis_gianlucca'

# %%
directory = 'data/03_processed/cruises/'
dss = [pd.read_csv(directory + file) for file in os.listdir(directory)]
names = os.listdir(directory)
transects = {}
for i in range(len(names)):
    transects[names[i]] = dss[i]

# %%
data.processing.downsample_lat(transects['JC069a'], -0.005, 'bx_500')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\envs\mthesis\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\miniconda3\envs\mthesis\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\miniconda3\envs\mthesis\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lon'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
transects['JC069a']
# Out:
#      Unnamed: 0          rho        lat     rho_1000     rho_2000  \
# 0           0.0          NaN        NaN          NaN          NaN
# 1         500.0          NaN        NaN          NaN          NaN
# 2        1000.0          NaN        NaN          NaN          NaN
# 3        1500.0          NaN        NaN          NaN          NaN
# 4        2000.0          NaN        NaN          NaN          NaN
# ..          ...          ...        ...          ...          ...
# 907    453500.0  1026.726775 -58.502369  1026.728208  1026.730554
# 908    454000.0  1026.726804 -58.506756  1026.726790  1026.728828
# 909    454500.0  1026.727491 -58.511147  1026.727147  1026.727678
# 910    455000.0  1026.729427 -58.515539  1026.728459  1026.727624
# 911    455500.0  1026.730067 -58.519932  1026.729747  1026.728447
#
#         rho_5000    rho_10000        bx_500       bx_1000       bx_2000  \
# 0            NaN          NaN           NaN           NaN           NaN
# ...

# %%
transects.keys()
# Out:
# dict_keys(['JC069a', 'JR16002a', 'JR17001a', 'JR17001b', 'JR18002a', 'JR18002b'])

# %%
lat = {}
for i in list(transects.keys()):
    lat[i+'_lat'] = transects[i]['lat']
lat = pd.DataFrame(lat)

bx_500 = {}
for i in list(transects.keys()):
    bx_500[i] = transects[i]['bx_500']
bx_500 = pd.DataFrame(bx_500)

bx_1000 = {}
for i in list(transects.keys()):
    bx_1000[i] = transects[i]['bx_1000']
bx_1000 = pd.DataFrame(bx_1000)

bx_2000 = {}
for i in list(transects.keys()):
    bx_2000[i] = transects[i]['bx_2000']
bx_2000 = pd.DataFrame(bx_2000)

bx_5000 = {}
for i in list(transects.keys()):
    bx_5000[i] = transects[i]['bx_5000']
bx_5000 = pd.DataFrame(bx_5000)

# %%
transects.keys()
# Out:
# dict_keys(['JC069a', 'JR16002a', 'JR17001a', 'JR17001b', 'JR18002a', 'JR18002b'])

# %%
a = xr.DataArray(bx_500['JC069a'].values, coords={'lat':lat['JC069a_lat'].values}).sortby('lat')
b = xr.DataArray(bx_500['JR16002a'].values, coords={'lat':lat['JR16002a_lat'].values}).sortby('lat')
c = xr.DataArray(bx_500['JR17001a'].values, coords={'lat':lat['JR17001a_lat'].values}).sortby('lat')
d = xr.DataArray(bx_500['JR17001b'].values, coords={'lat':lat['JR17001b_lat'].values}).sortby('lat')
e = xr.DataArray(bx_500['JR18002a'].values, coords={'lat':lat['JR18002a_lat'].values}).sortby('lat')
f = xr.DataArray(bx_500['JR18002b'].values, coords={'lat':lat['JR18002b_lat'].values}).sortby('lat')

# %%
JC069a = transects['JC069a']
JR16002a = transects['JR16002a']
JR17001a = transects['JR17001a']
JR17001b = transects['JR17001b']
JR18002a = transects['JR18002a']
JR18002b = transects['JR18002b']

# %%
JC069a
# Out:
#      Unnamed: 0          rho        lat     rho_1000     rho_2000  \
# 0           0.0          NaN        NaN          NaN          NaN
# 1         500.0          NaN        NaN          NaN          NaN
# 2        1000.0          NaN        NaN          NaN          NaN
# 3        1500.0          NaN        NaN          NaN          NaN
# 4        2000.0          NaN        NaN          NaN          NaN
# ..          ...          ...        ...          ...          ...
# 907    453500.0  1026.726775 -58.502369  1026.728208  1026.730554
# 908    454000.0  1026.726804 -58.506756  1026.726790  1026.728828
# 909    454500.0  1026.727491 -58.511147  1026.727147  1026.727678
# 910    455000.0  1026.729427 -58.515539  1026.728459  1026.727624
# 911    455500.0  1026.730067 -58.519932  1026.729747  1026.728447
#
#         rho_5000    rho_10000        bx_500       bx_1000       bx_2000  \
# 0            NaN          NaN           NaN           NaN           NaN
# ...

# %%
fig, (ax0, ax1, ax2, ax3, ax4, ax5) = plt.subplots(ncols=6, figsize=(14,10), sharey=True)
fig.suptitle('No rolling mean', fontsize=16)
bx = bx_500
axes = [ax0, ax1, ax2, ax3, ax4, ax5]
keys = list(bx.keys())
for i in range(len(axes)): 
    axes[i].plot(bx.iloc[:,i], lat.iloc[:,i])
    axes[i].grid()
    axes[i].set_xlim([-5e-7,5e-7])
    axes[i].set_title(keys[i])
    axes[i].set_xlabel('$B_{x}$')
ax0.set_ylabel('Latitude')
plt.savefig('results/analysis/25-02-22/transects_500.png', format='png')

# %%
fig, (ax0, ax1, ax2, ax3, ax4, ax5) = plt.subplots(ncols=6, figsize=(14,10), sharey=True)
fig.suptitle('1000 m rolling mean', fontsize=16)
bx = bx_1000
axes = [ax0, ax1, ax2, ax3, ax4, ax5]
keys = list(bx.keys())
for i in range(len(axes)): 
    axes[i].plot(bx.iloc[:,i], lat.iloc[:,i])
    axes[i].grid()
    axes[i].set_xlim([-5e-7,5e-7])
    axes[i].set_title(keys[i])
    axes[i].set_xlabel('$B_{x}$')
ax0.set_ylabel('Latitude')
plt.savefig('results/analysis/25-02-22/transects_1000.png', format='png')

# %%
fig, (ax0, ax1, ax2, ax3, ax4, ax5) = plt.subplots(ncols=6, figsize=(14,10), sharey=True)
fig.suptitle('2000 m rolling mean', fontsize=16)
bx = bx_2000
axes = [ax0, ax1, ax2, ax3, ax4, ax5]
keys = list(bx.keys())
for i in range(len(axes)): 
    axes[i].plot(bx.iloc[:,i], lat.iloc[:,i])
    axes[i].grid()
    axes[i].set_xlim([-5e-7,5e-7])
    axes[i].set_title(keys[i])
    axes[i].set_xlabel('$B_{x}$')
ax0.set_ylabel('Latitude')
plt.savefig('results/analysis/25-02-22/transects_2000.png', format='png')

# %%
fig, (ax0, ax1, ax2, ax3, ax4, ax5) = plt.subplots(ncols=6, figsize=(14,10), sharey=True)
fig.suptitle('5000 m rolling mean', fontsize=16)
bx = bx_5000
axes = [ax0, ax1, ax2, ax3, ax4, ax5]
keys = list(bx.keys())
for i in range(len(axes)): 
    axes[i].plot(bx.iloc[:,i], lat.iloc[:,i])
    axes[i].grid()
    axes[i].set_xlim([-5e-7,5e-7])
    axes[i].set_title(keys[i])
    axes[i].set_xlabel('$B_{x}$')
ax0.set_ylabel('Latitude')
plt.savefig('results/analysis/25-02-22/transects_5000.png', format='png')

# %%
bx_500
# Out:
#       JC069a      JR16002a      JR17001a      JR17001b      JR18002a  \
# 0        NaN           NaN           NaN           NaN           NaN
# 1        NaN           NaN           NaN           NaN           NaN
# 2        NaN           NaN -5.682078e-08  1.591852e-09  3.838569e-09
# 3        NaN           NaN -9.930593e-09  1.721987e-08 -5.197746e-09
# 4        NaN  4.260027e-09 -2.741909e-08  3.783439e-09 -1.013806e-08
# ...      ...           ...           ...           ...           ...
# 1209     NaN           NaN -1.059900e-08           NaN           NaN
# 1210     NaN           NaN -1.358608e-09           NaN           NaN
# 1211     NaN           NaN -6.827864e-09           NaN           NaN
# 1212     NaN           NaN  1.269168e-08           NaN           NaN
# 1213     NaN           NaN -1.526894e-09           NaN           NaN
#
#           JR18002b
# 0              NaN
# 1              NaN
# 2    -1.665749e-08
# 3    -4.759344e-08
# 4    -6.081371e-08
# ...

# %% [markdown]
# ## Bathymetry

# %%
etopo1 = xr.open_dataset(r'data/01_raw/ETOPO1_Bed_g_gmt4.grd',engine='netcdf4')

# %%
etopo1_sel = etopo1.sel(x=slice(-75,-50), y=slice(-65,-52))

import cmocean.cm as cm
from matplotlib.cm import ScalarMappable
bath = etopo1_sel

fig= plt.figure(figsize=(14,12))
ax = plt.axes(projection=ccrs.PlateCarree())
#ax.set_extent([-62,-52,-62,-52])
x = bath.x
y = bath.y
z = bath.z
vmin = z.min()
vmax = z.max()
topo_f = ax.contourf(x, y, z, 
                cmap = cm.deep_r,
                    vmin = vmin,
                    vmax = 0,
                #    norm=MidpointNormalize(
                #        midpoint=-1000,
                #        vmin=vmin,lines
                #        vmax=0
                #     ),
                levels=20
                )
plt.colorbar(ScalarMappable(norm=topo_f.norm, cmap=topo_f.cmap), pad=0.02)

ax.coastlines(zorder=100)
ax.add_feature(cartopy.feature.LAND, color='green', zorder=50)
gl = ax.gridlines(draw_labels=True, linestyle='-.', color='gray')
gl.xlabels_top = False
gl.ylabels_right = False
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %% [markdown]
# ## SOCAT

# %%
df = pd.read_csv('data/01_raw/SOCATv2021_SouthernOceans.tsv', sep='\t', header=1232)
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (0,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18624/1191279622.py in <module>
# ----> 1 df = pd.read_csv('data/01_raw/SOCATv2021_SouthernOceans.tsv', sep='\t', header=1232)
#
# ~\miniconda3\envs\mthesis\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.to_csv('data/01_raw/dataset.csv')

# %%
df = pd.read_csv('data/01_raw/dataset.csv')
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (1,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = df.drop(['Unnamed: 0', 'version', 'GVCO2 [umol/mol]', 'xCO2water_equ_dry [umol/mol]', 'xCO2water_SST_dry [umol/mol]',
         'pCO2water_equ_wet [uatm]', 'pCO2water_SST_wet [uatm]', 'fCO2water_equ_wet [uatm]', 'fCO2water_SST_wet [uatm]', 'fCO2rec [uatm]',
         'fCO2rec_src', 'fCO2rec_flag', 'NCEP_SLP [hPa]', 'Pequ [hPa]', 'PPPP [hPa]'
         ], axis=1)

# %%
df['longitude'] = df['longitude [dec.deg.E]']
df['latitude'] = df['latitude [dec.deg.N]']
df = df.drop(['longitude [dec.deg.E]', 'latitude [dec.deg.N]'], axis=1)
df['longitude'] = utils.utils.convert_lon_center(df['longitude'])

# %%
df['longitude'] = utils.utils.convert_lon_center(df['longitude'], center='Atlantic')

# %%
df.max()
# Out:
# C:\Users\gian_\AppData\Local\Temp/ipykernel_18624/1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# QC_Flag                      D
# yr                        2021
# mon                         12
# day                         31
# hh                          23
# mm                          59
# ss                        60.0
# sample_depth [m]           5.0
# sal                     39.292
# SST [deg.C]             31.131
# Tequ [deg.C]              30.9
# WOA_SSS                 36.422
# ETOPO2_depth [m]        9291.0
# dist_to_land [km]       1000.0
# longitude            179.99997
# latitude              -29.8334
# dtype: object

# %%
df_sel = df.where(
    (df['longitude'] > -75) & 
    (df['longitude'] < -50) & 
    (df['latitude'] > -65) & 
    (df['latitude'] < -52)
    )

# %%
import dask.dataframe as dd
df = dd.read_csv('data/01_raw/dataset.csv')

# %%
df['longitude']
# Out:
# 0         -22.12505
# 1         -22.12586
# 2         -22.12660
# 3         -22.12762
# 4         -22.12907
#              ...
# 7382221    18.11660
# 7382222    18.12820
# 7382223    18.13920
# 7382224    18.15020
# 7382225    18.18100
# Name: longitude, Length: 7382226, dtype: float64

# %%
del(df_sel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18624/3885332192.py in <module>
# ----> 1 del(df_sel)
#
# NameError: name 'df_sel' is not defined

# %%
dd.to_

# %%
df_sel = df.where(
    (df['longitude'] > -70) &
    (df['longitude']) < -55
         ).dropna()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18624/2067790473.py in <module>
# ----> 1 df_sel = df.where(
#       2     (df['longitude'] > -70) &
#       3     (df['longitude']) < -55
#       4          ).dropna()
#
# ~\miniconda3\envs\mthesis\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\miniconda3\envs\mthesis\lib\site-packages\pandas\core\frame.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#   10734         try_cast=lib.no_default,
#   10735     ):
# > 10736         return super().where(cond, other, inplace, axis, level, errors, try_cast)
#   10737
#   10738     @deprecate_nonkeyword_arguments(
#
# ...

# %%
etopo1_sel = etopo1.sel(x=slice(-75,-50), y=slice(-65,-52))

import cmocean.cm as cm
from matplotlib.cm import ScalarMappable
bath = etopo1_sel

fig= plt.figure(figsize=(14,12))
ax = plt.axes(projection=ccrs.SouthPolarStereo(central_longitude=-60))
ax.set_extent([-75,-50,-62,-55.5])
x = bath.x
y = bath.y
z = bath.z
vmin = z.min()
vmax = z.max()
topo_f = ax.contourf(x, y, z, 
                cmap = cm.deep_r,
                    vmin = vmin,
                    vmax = 0,
                #    norm=MidpointNormalize(
                #        midpoint=-1000,
                #        vmin=vmin,lines
                #        vmax=0
                #     ),
                levels=20,
                transform=ccrs.PlateCarree()
                )
#plt.colorbar(ScalarMappable(norm=topo_f.norm, cmap=topo_f.cmap), pad=0.02)

ax.coastlines(zorder=100)
ax.add_feature(cartopy.feature.LAND, color='green', zorder=50)
gl = ax.gridlines(draw_labels=True, linestyle='-.', color='gray')
gl.xlabels_top = False
gl.ylabels_right = False

ax.scatter(df['longitude'], df['latitude'], c='black', s=0.1,transform=ccrs.PlateCarree())
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...
