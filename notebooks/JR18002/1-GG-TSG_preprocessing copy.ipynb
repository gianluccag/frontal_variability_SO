# %% [markdown]
# # Prepocessing and data selection

# %%
from GG_mthesis import *
import metpy
import metpy.calc as mpcalc
from metpy.cbook import get_test_data
from metpy.units import units
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\gian_\\repos\\mthesis_gianlucca'

# %%
# sns.set_style('whitegrid')
# sns.set_palette('colorblind')
# sns.set(font_scale=1.2)

# %% [markdown]
# ## Reshaping

# %%
#define the path
path = '.\\data\\01_raw\\JR18002\\b2021675.nc'

#open the dataset with the defined path
ds_orig = xr.open_dataset(path) 

#Squeeze eliminates dimensions of length 0 and 1. Drop REFMAX as it is not needed. Swap MAXT (count) with TIME 
#to make TIME unique dimension (MAXT is a count a not needed, you can access the same with .isel). Rename coords to
#my standard.
ds = ds_orig.squeeze().drop_dims('REFMAX').swap_dims({'MAXT':'TIME'}).rename({
    'LONGITUDE':'lon','LATITUDE':'lat','TIME':'time','DEPTH':'depth'})

#Definition of new time attributes (datetime). Retrieved from original dataset and modified.
new_time_attr = {'long_name': 'Chronological DateTime Date',
 'standard_name': 'time',
 'ancillary_variables': 'TIME_SEADATANET_QC',
 'axis': 'T',
 'valid_min': 0.0,
 'valid_max': 2500000.0,
 'sdn_parameter_urn': 'SDN:P01::CJDY1101',
 'sdn_parameter_name': 'DateTime (chronological)',
 'sdn_uom_name': 'Days',
 'sdn_uom_urn': 'SDN:P06::UTAA'}

#Pull out the index (a CFTimeIndex) and use built in to_datetimeindex method.
datetimeindex = ds.indexes['time'].to_datetimeindex()

#Replace CFTimeIndex with DateTimeIndex:
ds['time'] = datetimeindex

#Attach new attributes
ds['time'].attrs = new_time_attr
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\xarray\coding\times.py:174: CFWarning: this date/calendar/year zero convention is not supported by CF
#   cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
# C:\Users\gian_\AppData\Local\Temp/ipykernel_7404/1673175918.py:26: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'julian', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   datetimeindex = ds.indexes['time'].to_datetimeindex()

# %% [markdown]
# ## Bathmetry - data selection

# %%
etopo1 = xr.open_dataset(r'data/01_raw/ETOPO1_Bed_g_gmt4.grd',engine='netcdf4')
etopo1 = etopo1.sel(x=slice(-62,-52), y=slice(-64,-52))

# %%
import matplotlib.colors as colors
class MidpointNormalize(colors.Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))

# %%
ds_ACC_fronts = xr.load_dataset(r'data\03_processed\geo_fronts\park\62985.nc')

# %%
def sel_Park_region(dataset):
    data_lat = [
        dataset['LatNB'].values,
        dataset['LatSAF'].values,
        dataset['LatPF'].values,
        dataset['LatSACCF'].values,
        dataset['LatSB'].values,
    ]

    data_lon = [
        dataset['LonNB'].values,
        dataset['LonSAF'].values,
        dataset['LonPF'].values,
        dataset['LonSACCF'].values,
        dataset['LonSB'].values,
    ]

    index_front = ['NB', 'SAF', 'PF', 'SACCF', 'SB']


    df_fronts = pd.DataFrame(columns=['longitude','latitude','front'])
    for i in range(5):
        df_aux = pd.DataFrame({'longitude':data_lon[i], 'latitude':data_lat[i],'front':index_front[i]})
        df_fronts = df_fronts.append(df_aux)
    df_fronts = df_fronts.reset_index(drop=True)

    df_fronts_sel = df_fronts.where(
        (df_fronts['longitude'] > -62) & 
        (df_fronts['longitude'] < -52) & 
        (df_fronts['latitude'] > -62) & 
        (df_fronts['latitude'] < -52)
        ).dropna().reset_index()
    df_front_sel = df_fronts_sel.set_index(['front',df_fronts_sel.index]).drop('index',1)
    return df_front_sel

# %%
df_front_sel = sel_Park_region(ds_ACC_fronts)
# Out:
# C:\Users\gian_\AppData\Local\Temp/ipykernel_7404/662591249.py:33: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_front_sel = df_fronts_sel.set_index(['front',df_fronts_sel.index]).drop('index',1)

# %%
df = ds.to_dataframe()

df = df.where(
    (df['lon'] > -62) & 
     (df['lon'] < -52) & 
     (df['lat'] > -60.2) & 
     (df['lat'] < -55)).dropna(how='all')

# %%
from GG_mthesis.d01_data.processing import rmap 
ax = rmap.plot_region()
scat = ax.scatter(df['lon'], df['lat'], c=df.index, cmap='autumn', s=2)
cbar = plt.colorbar(scat, location='bottom', pad=0.05, ax=ax)
cbar.ax.set_xticklabels(pd.to_datetime(cbar.get_ticks()).strftime(date_format='%r %d %b'), rotation=22.5)
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# c:\users\gian_\repos\mthesis_gianlucca\src\GG_mthesis\d01_data\processing.py:52: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_front_sel = df_fronts_sel.set_index(['front',df_fronts_sel.index]).drop('index',1)
# C:\Users\gian_\AppData\Local\Temp/ipykernel_7404/781745850.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_xticklabels(pd.to_datetime(cbar.get_ticks()).strftime(date_format='%r %d %b'), rotation=22.5)
# [Text(1.5402e+18, 0, '09:20:00 AM 22 Oct'),
#  Text(1.5404e+18, 0, '04:53:20 PM 24 Oct'),
#  Text(1.5406e+18, 0, '12:26:40 AM 27 Oct'),
#  Text(1.5408e+18, 0, '08:00:00 AM 29 Oct'),
#  Text(1.541e+18, 0, '03:33:20 PM 31 Oct'),
#  Text(1.5412e+18, 0, '11:06:40 PM 02 Nov'),
#  Text(1.5414e+18, 0, '06:40:00 AM 05 Nov'),
#  Text(1.5416e+18, 0, '02:13:20 PM 07 Nov'),
#  Text(1.5418e+18, 0, '09:46:40 PM 09 Nov')]

# %%
df_sel_1 = df.loc['2018-10-28 04':'2018-10-31 00']
ax = rmap.plot_region()
scat = ax.scatter(df_sel_1['lon'], df_sel_1['lat'], c=df_sel_1.index, cmap='autumn', s=2, transform=ccrs.PlateCarree())
cbar = plt.colorbar(scat, location='bottom', pad=0.05, ax=ax)
cbar.ax.set_xticklabels(pd.to_datetime(cbar.get_ticks()).strftime(date_format='%r %d %b'), rotation=22.5)
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# c:\users\gian_\repos\mthesis_gianlucca\src\GG_mthesis\d01_data\processing.py:52: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_front_sel = df_fronts_sel.set_index(['front',df_fronts_sel.index]).drop('index',1)
# C:\Users\gian_\AppData\Local\Temp/ipykernel_7404/1456950764.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_xticklabels(pd.to_datetime(cbar.get_ticks()).strftime(date_format='%r %d %b'), rotation=22.5)
# [Text(1.54065e+18, 0, '02:20:00 PM 27 Oct'),
#  Text(1.5407e+18, 0, '04:13:20 AM 28 Oct'),
#  Text(1.54075e+18, 0, '06:06:40 PM 28 Oct'),
#  Text(1.5408e+18, 0, '08:00:00 AM 29 Oct'),
#  Text(1.54085e+18, 0, '09:53:20 PM 29 Oct'),
#  Text(1.5409e+18, 0, '11:46:40 AM 30 Oct'),
#  Text(1.54095e+18, 0, '01:40:00 AM 31 Oct')]

# %%
df_sel_2 = df.loc['2018-11-02 20 ':'2018-11-06 20']
ax = rmap.plot_region()
scat = ax.scatter(df_sel_2['lon'], df_sel_2['lat'], c=df_sel_2.index, cmap='autumn', s=2, transform=ccrs.PlateCarree())
cbar = plt.colorbar(scat, location='bottom', pad=0.05, ax=ax)
cbar.ax.set_xticklabels(pd.to_datetime(cbar.get_ticks()).strftime(date_format='%r %d %b'), rotation=22.5)
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# c:\users\gian_\repos\mthesis_gianlucca\src\GG_mthesis\d01_data\processing.py:52: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_front_sel = df_fronts_sel.set_index(['front',df_fronts_sel.index]).drop('index',1)
# C:\Users\gian_\AppData\Local\Temp/ipykernel_7404/679957691.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_xticklabels(pd.to_datetime(cbar.get_ticks()).strftime(date_format='%r %d %b'), rotation=22.5)
# [Text(1.5412e+18, 0, '11:06:40 PM 02 Nov'),
#  Text(1.54125e+18, 0, '01:00:00 PM 03 Nov'),
#  Text(1.5413e+18, 0, '02:53:20 AM 04 Nov'),
#  Text(1.54135e+18, 0, '04:46:40 PM 04 Nov'),
#  Text(1.5414e+18, 0, '06:40:00 AM 05 Nov'),
#  Text(1.54145e+18, 0, '08:33:20 PM 05 Nov'),
#  Text(1.5415e+18, 0, '10:26:40 AM 06 Nov'),
#  Text(1.54155e+18, 0, '12:20:00 AM 07 Nov')]

# %% [markdown]
# ## functions

# %%
def QC_count(dataframe):
    position_QC = dataframe['POSITION_SEADATANET_QC'].value_counts()
    depth_QC = dataframe['DEPTH_SEADATANET_QC'].value_counts()
    time_QC = dataframe['TIME_SEADATANET_QC'].value_counts()
    conduc_QC = dataframe['CNDCSG01_SEADATANET_QC'].value_counts()
    PS_uncal_QC = dataframe['PSALSG01_SEADATANET_QC'].value_counts()
    PS_cal_QC = dataframe['PSALSU01_SEADATANET_QC'].value_counts()
    T_hull_QC = dataframe['TEMPHU01_SEADATANET_QC'].value_counts()
    T_tsg_QC = dataframe['TMESSG01_SEADATANET_QC'].value_counts()

    QC =[position_QC, depth_QC, time_QC, conduc_QC, PS_uncal_QC, PS_cal_QC, T_hull_QC, T_tsg_QC]

    df_QC = pd.DataFrame(QC)

    return df_QC

def drop_QC_var(dataframe):
    df = dataframe.drop(['SDN_CRUISE', 'crs', 'SDN_EDMO_CODE', 'SDN_STATION', 'SDN_LOCAL_CDI_ID',
       'SDN_BOT_DEPTH', 'POSITION_SEADATANET_QC', 'depth',
       'DEPTH_SEADATANET_QC', 'TIME_SEADATANET_QC', 'ACYCAA01_SEADATANET_QC',
       'ACYCAA01', 'ATTNDR01_SEADATANET_QC', 'ATTNDR01', 'CPHLUMTF_SEADATANET_QC',
       'CPHLUMTF', 'POPTDR01_SEADATANET_QC', 'POPTDR01', 'PSALSG01_SEADATANET_QC',
       'PSALSU01_SEADATANET_QC', 'TEMPSU01_SEADATANET_QC','TMESSG01_SEADATANET_QC'], axis=1)
    return df

def nan_count(dataframe):
    aux = {}
    for var in dataframe.columns:
        index = var
        value = dataframe[var].isna().sum()
        aux[index] = [value]
    return pd.DataFrame(aux, index=['Nan_count']).transpose()

def time_difference(time_array):
    time_dif = []
    for i in range(len(time_array)-1):
        time_dif.append(time_array[i+1] - time_array[i])
    time_dif = np.array(time_dif).astype('timedelta64[s]').astype('float')
    return time_dif

def histograms(vel, distance):
    #Let's plot the distances and vessel speed in a histogram, with a cut-off line at 4ms-1

    fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(16,8))

    ax0.hist(vel, color='grey', alpha = 0.5, bins=30)

    ax0.axvline(x=np.median(vel), label=str(('Median = ') + str(round(np.median(vel),2)) 
        + str(' m')), color='black', linestyle='-.')
    ax0.axvline(x=np.mean(vel), label=str(('Mean = ') + str(round(np.mean(vel),2)) 
        + str(' m')), color='black', linestyle='--')
    ax0.axvline(x=np.quantile(vel, .10), label=str(('Quantile 10 = ') + str(round(np.quantile(vel, .10),2)) 
        + str(' m')), color='black', linestyle=':',)
    ax0.axvline(x=np.quantile(vel, .90), label=str(('Quantile 90 = ') + str(round(np.quantile(vel, .90),2)) 
        + str(' m')), color='black', linestyle=':')
    ax0.legend(loc='upper right')

    ax1.hist(distance, color='grey', alpha =0.5, bins=30)

    ax1.axvline(x=np.median(distance), label=str(('Median = ') + str(round(np.median(distance),2)) 
        + str(' m')), color='black', linestyle='-.')
    ax1.axvline(x=np.mean(distance), label=str(('Mean = ') + str(round(np.mean(distance),2)) 
        + str(' m')), color='black', linestyle='--')
    ax1.axvline(x=np.quantile(distance, .10), label=str(('Quantile 10 = ') + str(round(np.quantile(distance, .10),2)) 
        + str(' m')), color='black', linestyle=':',)
    ax1.axvline(x=np.quantile(distance, .90), label=str(('Quantile 90 = ') + str(round(np.quantile(distance, .90),2)) 
        + str(' m')), color='black', linestyle=':')
    ax1.legend(loc='upper right')

    ax0.axvline(x=2, label='speed cut off = 2ms-1 (120 m)', color='red', linestyle='-')
    ax0.axvline(x=10, label='speed cut off = 10ms-1 (600 m)', color='red', linestyle='-')

    ax1.axvline(x=120, label='speed cut off = 2ms-1 (120 m)', color='red', linestyle='-')
    ax1.axvline(x=600, label='speed cut off = 10ms-1 (600 m)', color='red', linestyle='-')

    #ax1.set_xticks(np.arange(0, 460, 60))

    ax0.set(xlabel='Vessel speed (ms-1)')
    ax1.set(xlabel='Distance (m)')

    ax0.legend(loc='upper center')
    
def stats(**kwargs):
    for i in kwargs:
        print('Min(' + str(i) + '): ' + str(np.min(np.array(kwargs[i]))))
        print('Max(' + str(i) + '): ' + str(np.max(np.array(kwargs[i]))))
        print('Mean(' + str(i) + '): ' + str(np.mean(np.array(kwargs[i]))))
        print('Median(' + str(i) + '): ' + str(np.median(np.array(kwargs[i]))))
        print( )

# %% [markdown]
# ## df_sel_1

# %% [markdown]
# Method: I apply the count_flags function to the QC variables. If they are fine (only good values and interpolated values) drop
# it from the dataset (the QC variable).

# %%
df_sel_1 = df.loc['2018-10-28 04':'2018-10-31 00']

# %%
QC_count(df_sel_1)
# Out:
#                         49.0
# POSITION_SEADATANET_QC  4140
# DEPTH_SEADATANET_QC     4140
# TIME_SEADATANET_QC      4140
# CNDCSG01_SEADATANET_QC  4140
# PSALSG01_SEADATANET_QC  4140
# PSALSU01_SEADATANET_QC  4140
# TEMPHU01_SEADATANET_QC  4140
# TMESSG01_SEADATANET_QC  4140

# %%
df_sel_1 = drop_QC_var(df_sel_1)

# %%
nan_count(df_sel_1)
# Out:
#                         Nan_count
# lat                             0
# lon                             0
# CNDCSG01_SEADATANET_QC          0
# CNDCSG01                        0
# PSALSG01                        0
# PSALSU01                        0
# TEMPHU01_SEADATANET_QC          0
# TEMPHU01                        0
# TEMPSU01                        0
# TMESSG01                        0

# %%
#Let's calculate the distances
distance_sel_1 = gsw.distance(df_sel_1['lon'], df_sel_1['lat'])

#And the cumulative distance
distance_cum_1 = np.insert(np.cumsum(distance_sel_1), 0, 0)

df_sel_1['distance_cum'] = distance_cum_1
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\gsw\geostrophy.py:187: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   lon = lon[np.newaxis, :]
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\gsw\geostrophy.py:188: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   lat = lat[np.newaxis, :]

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.plot(df_sel_1.index, -df_sel_1['distance_cum'], c='green')
ax1 = ax.twinx()
ax1.scatter(df_sel_1.index, df_sel_1['TMESSG01'], s=0.5)
ax.grid(axis='both', which='both')

# %%
time_dif_sel_1 = time_difference(df_sel_1.index)

# %%
vel_sel_1 = distance_sel_1/time_dif_sel_1

# %%
fig, (ax0,ax1,ax2) = plt.subplots(nrows=3, figsize=(16,8), sharex=True)
ax0.plot(df_sel_1.index[1:], distance_sel_1)
ax0.set(ylabel='Distances (m)')

ax1.plot(df_sel_1.index[1:], vel_sel_1)
ax1.set(ylabel='Vessel velocity (m/s)')

ax2.plot(df_sel_1.index, df_sel_1['TMESSG01'], color='orange')
ax2.set(xlabel='Time', ylabel='T (°C)')
ax2.yaxis.label.set_color('orange')
ax3 = ax2.twinx()
ax3.plot(df_sel_1.index, df_sel_1['PSALSU01'], color='green')
ax3.set(ylabel='SP (PSU)')
ax3.yaxis.label.set_color('green')

# %%
histograms(vel_sel_1, distance_sel_1)

# %%
stats(time=time_dif_sel_1, distance=distance_sel_1)
# Out:
# Min(time): 59.0
# Max(time): 60.0
# Mean(time): 59.73882580333414
# Median(time): 60.0
#
# Min(distance): 0.0
# Max(distance): 366.94447122948867
# Mean(distance): 119.88464448596416
# Median(distance): 12.798872379739652

# %%
df_1 = df_sel_1
df_1['distance_aux'] = np.insert(distance_sel_1, 0, -999)
df_1['vel'] = np.insert(vel_sel_1, 0, 5.5)
df_1 = df_1.where(df_1['distance_aux'] > 120)
#df_sel_1 = df_sel_1[df_sel_1['vel'] > 2]
df_1 = df_1.drop('distance_aux', axis=1)

# distance_1 = gsw.distance(df_1['lon'], df_1['lat'])
# distance_cum = np.insert(np.cumsum(distance_1), 0, 0)
# df_1['distance_cum'] = distance_cum

# %%
distance_1_aux = gsw.distance(df_1['lon'].dropna(), df_1['lat'].dropna())
# distance_1_aux = distance_1_aux[~np.isnan(distance_1_aux)]
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\gsw\geostrophy.py:187: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   lon = lon[np.newaxis, :]
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\gsw\geostrophy.py:188: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   lat = lat[np.newaxis, :]

# %%
time_dif_1_aux = time_difference(df_1.dropna(axis=0).index)

# %%
#vel_1 = distance_1/time_dif_1

# %%
histograms(df_1['vel'], distance_1_aux)

# %%
stats(time=time_dif_1_aux/60, distance=distance_1_aux, velocity=df_1['vel'].dropna())
# Out:
# Min(time): 0.9833333333333333
# Max(time): 258.98333333333335
# Mean(time): 2.6410379369138957
# Median(time): 1.0
#
# Min(distance): 121.36752475989269
# Max(distance): 5175.041325994017
# Mean(distance): 310.6309619673707
# Median(distance): 316.9834227134171
#
# Min(velocity): 2.0121614743399547
# Max(velocity): 6.219397817448961
# Mean(velocity): 5.052796439699521
# Median(velocity): 5.28072954118404

# %%
#Let's plot what we have got so far

fig, (ax0,ax1) = plt.subplots(nrows=2, figsize=(16,8))#, sharex=True)
ax0.plot(df_1.index, df_1['distance_cum'], color='black')
ax0.set(ylabel='Distance travelled (km)')

ax1.plot(df_1['distance_cum']/1000, df_1['vel'], color='red')
ax1.set(xlabel='Cumulative distance (km)', ylabel='Vessel velocity (m/s)')
ax2 = ax1.twiny()
ax2.plot(df_1.index, df_1['vel'], color='blue')

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.plot(df_1.index, -df_1['distance_cum'], c='green')
ax1 = ax.twinx()
ax1.scatter(df_1.index, df_1['TMESSG01'], s=0.5)
ax.grid(axis='both', which='both')

# %% [markdown]
# ## df_sel_2

# %% [markdown]
# Method: I apply the count_flags function to the QC variables. If they are fine (only good values and interpolated values) drop
# it from the dataset (the QC variable).

# %%
df_sel_2 = df.loc['2018-11-02 20 ':'2018-11-06 20']

# %%
QC_count(df_sel_2)
# Out:
#                           49.0  51.0
# POSITION_SEADATANET_QC  5236.0   NaN
# DEPTH_SEADATANET_QC     5236.0   NaN
# TIME_SEADATANET_QC      5236.0   NaN
# CNDCSG01_SEADATANET_QC  5227.0   9.0
# PSALSG01_SEADATANET_QC  5227.0   9.0
# PSALSU01_SEADATANET_QC  5227.0   9.0
# TEMPHU01_SEADATANET_QC  5227.0   9.0
# TMESSG01_SEADATANET_QC  5223.0  13.0

# %%
df_sel_2 = drop_QC_var(df_sel_2)

# %%
nan_count(df_sel_2)
# Out:
#                         Nan_count
# lat                             0
# lon                             0
# CNDCSG01_SEADATANET_QC          0
# CNDCSG01                        0
# PSALSG01                        0
# PSALSU01                        0
# TEMPHU01_SEADATANET_QC          0
# TEMPHU01                        0
# TEMPSU01                        0
# TMESSG01                        0

# %%
#Let's calculate the distances
distance_sel_2 = gsw.distance(df_sel_2['lon'], df_sel_2['lat'])

#And the cumulative distance
distance_cum_2 = np.insert(np.cumsum(distance_sel_2), 0, 0)

df_sel_2['distance_cum'] = distance_cum_2
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\gsw\geostrophy.py:187: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   lon = lon[np.newaxis, :]
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\gsw\geostrophy.py:188: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   lat = lat[np.newaxis, :]

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.plot(df_sel_2.index, df_sel_2['distance_cum'], c='green')
ax1 = ax.twinx()
ax1.scatter(df_sel_2.index, df_sel_2['TMESSG01'], s=0.5)
ax.grid(axis='both', which='both')

# %%
time_dif_sel_2 = time_difference(df_sel_2.index)

# %%
vel_sel_2 = distance_sel_2/time_dif_sel_2

# %%
fig, (ax0,ax1,ax2) = plt.subplots(nrows=3, figsize=(16,8), sharex=True)
df_plot = df_sel_2
ax0.plot(df_plot.index[1:], distance_sel_2)
ax0.set(ylabel='Distances (m)')

ax1.plot(df_plot.index[1:], vel_sel_2)
ax1.set(ylabel='Vessel velocity (m/s)')

ax2.plot(df_plot.index, df_plot['TMESSG01'], color='orange')
ax2.set(xlabel='Time', ylabel='T (°C)')
ax2.yaxis.label.set_color('orange')
ax3 = ax2.twinx()
ax3.plot(df_plot.index, df_plot['PSALSU01'], color='green')
ax3.set(ylabel='SP (PSU)')
ax3.yaxis.label.set_color('green')

# %%
histograms(vel_sel_2, distance_sel_2)

# %%
stats(time=time_dif_sel_2, distance=distance_sel_2)
# Out:
# Min(time): 59.0
# Max(time): 60.0
# Mean(time): 59.740019102196754
# Median(time): 60.0
#
# Min(distance): 0.0
# Max(distance): 382.7428146692561
# Mean(distance): 112.16167446650852
# Median(distance): 6.984932373603046

# %%
df_2 = df_sel_2
df_2['distance_aux'] = np.insert(distance_sel_2, 0, -999)
df_2['vel'] = np.insert(vel_sel_2, 0, 5.5)
df_2 = df_2.where(df_2['distance_aux'] > 120)
#df_sel_1 = df_sel_1[df_sel_1['vel'] > 2]
df_2 = df_2.drop('distance_aux', axis=1)

# distance_1 = gsw.distance(df_1['lon'], df_1['lat'])
# distance_cum = np.insert(np.cumsum(distance_1), 0, 0)
# df_1['distance_cum'] = distance_cum

# %%
distance_2_aux = gsw.distance(df_2['lon'].dropna(), df_2['lat'].dropna())
# distance_1_aux = distance_1_aux[~np.isnan(distance_1_aux)]
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\gsw\geostrophy.py:187: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   lon = lon[np.newaxis, :]
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\gsw\geostrophy.py:188: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   lat = lat[np.newaxis, :]

# %%
time_dif_2_aux = time_difference(df_2.dropna(axis=0).index)

# %%
#vel_1 = distance_1/time_dif_1

# %%
histograms(df_2['vel'], distance_2_aux)

# %%
stats(time=time_dif_2_aux/60, distance=distance_2_aux, velocity=df_2['vel'].dropna())
# Out:
# Min(time): 0.9833333333333333
# Max(time): 889.0
# Mean(time): 2.6516089541797836
# Median(time): 1.0
#
# Min(distance): 123.27143315061865
# Max(distance): 1171.94165544961
# Mean(distance): 300.9294566166105
# Median(distance): 307.72051962909586
#
# Min(velocity): 2.089346324586757
# Max(velocity): 6.430009967390866
# Mean(velocity): 4.974878213636912
# Median(velocity): 5.139245915444515

# %%
#Let's plot what we have got so far

fig, (ax0,ax1) = plt.subplots(nrows=2, figsize=(16,8))#, sharex=True)
ax0.plot(df_2.index, df_2['distance_cum'], color='black')
ax0.set(ylabel='Distance travelled (km)')

ax1.plot(df_2['distance_cum']/1000, df_2['vel'], color='red')
ax1.set(xlabel='Cumulative distance (km)', ylabel='Vessel velocity (m/s)')
ax2 = ax1.twiny()
ax2.plot(df_2.index, df_2['vel'], color='blue')

# %%
fig, ax = plt.subplots(figsize=(16,8))
df_plot = df_2
ax.plot(df_plot.index, df_plot['distance_cum']/1000, c='green')
ax.set_ylabel('Cumulative distance (km)')
ax1 = ax.twinx()
ax1.scatter(df_plot.index, df_plot['TMESSG01'], s=0.5, c='orange')
ax1.set(xlabel='Time', ylabel='T (°C)')
ax.grid(axis='both', which='both')
ax1.yaxis.label.set_color('orange')

# %%
df_2
# Out:
#                                   lat        lon  CNDCSG01_SEADATANET_QC  \
# time
# 2018-11-03 05:44:00.000064        NaN        NaN                     NaN
# 2018-11-03 05:44:59.999584 -60.197357 -55.116123                    49.0
# 2018-11-03 05:46:00.000384 -60.194805 -55.117786                    49.0
# 2018-11-03 05:46:59.999872 -60.192261 -55.119408                    49.0
# 2018-11-03 05:47:59.999392 -60.189709 -55.121105                    49.0
# ...                               ...        ...                     ...
# 2018-11-06 20:55:00.001152        NaN        NaN                     NaN
# 2018-11-06 20:56:00.001952        NaN        NaN                     NaN
# 2018-11-06 20:56:59.997600        NaN        NaN                     NaN
# 2018-11-06 20:57:59.998400        NaN        NaN                     NaN
# 2018-11-06 20:58:59.999200        NaN        NaN                     NaN
#
#                             CNDCSG01   PSALSG01   PSALSU01  \
# time
# 2018-11-03 05:44:00.000064       NaN        NaN        NaN
# 2018-11-03 05:44:59.999584  2.867795  34.034393  34.026199
# 2018-11-03 05:46:00.000384  2.868385  34.037643  34.029449
# 2018-11-03 05:46:59.999872  2.868835  34.038197  34.029999
# 2018-11-03 05:47:59.999392  2.869405  34.041245  34.033051
# ...                              ...        ...        ...
# 2018-11-06 20:55:00.001152       NaN        NaN        NaN
# 2018-11-06 20:56:00.001952       NaN        NaN        NaN
# 2018-11-06 20:56:59.997600       NaN        NaN        NaN
# 2018-11-06 20:57:59.998400       NaN        NaN        NaN
# 2018-11-06 20:58:59.999200       NaN        NaN        NaN
#
#                             TEMPHU01_SEADATANET_QC  TEMPHU01  TEMPSU01  \
# time
# 2018-11-03 05:44:00.000064                     NaN       NaN       NaN
# 2018-11-03 05:44:59.999584                    49.0  -0.67990  -0.69870
# 2018-11-03 05:46:00.000384                    49.0  -0.67485  -0.69260
# 2018-11-03 05:46:59.999872                    49.0  -0.67435  -0.68975
# 2018-11-03 05:47:59.999392                    49.0  -0.67815  -0.68650
# ...                                            ...       ...       ...
# 2018-11-06 20:55:00.001152                     NaN       NaN       NaN
# 2018-11-06 20:56:00.001952                     NaN       NaN       NaN
# 2018-11-06 20:56:59.997600                     NaN       NaN       NaN
# 2018-11-06 20:57:59.998400                     NaN       NaN       NaN
# 2018-11-06 20:58:59.999200                     NaN       NaN       NaN
#
#                             TMESSG01  distance_cum       vel
# time
# 2018-11-03 05:44:00.000064       NaN           NaN       NaN
# 2018-11-03 05:44:59.999584    0.4434    283.269549  4.801179
# 2018-11-03 05:46:00.000384    0.4498    581.559192  4.971494
# 2018-11-03 05:46:59.999872    0.4536    878.335580  5.030108
# 2018-11-03 05:47:59.999392    0.4577   1177.219973  5.065837
# ...                              ...           ...       ...
# 2018-11-06 20:55:00.001152       NaN           NaN       NaN
# 2018-11-06 20:56:00.001952       NaN           NaN       NaN
# 2018-11-06 20:56:59.997600       NaN           NaN       NaN
# 2018-11-06 20:57:59.998400       NaN           NaN       NaN
# 2018-11-06 20:58:59.999200       NaN           NaN       NaN
#
# [5236 rows x 12 columns]

# %%
fig, ax = plt.subplots(figsize=(16,8))
df_plot = df_2
ax.plot(df_plot.lat, df_plot['distance_cum']/1000, c='green')
ax.set_ylabel('Cumulative distance (km)')
ax1 = ax.twinx()
ax1.scatter(df_plot.lat, df_plot['TMESSG01'], s=0.5, c='orange')
ax1.set(xlabel='Time', ylabel='T (°C)')
ax.grid(axis='both', which='both')
ax1.yaxis.label.set_color('orange')

# %% [markdown]
# ## Density calculation

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (time: 25957)
# Coordinates:
#     lat                     (time) float64 -51.9 -51.9 -51.9 ... -53.96 -53.96
#     lon                     (time) float64 -58.44 -58.44 -58.44 ... -57.9 -57.9
#     depth                   (time) float32 6.5 6.5 6.5 6.5 ... 6.5 6.5 6.5 6.5
#   * time                    (time) datetime64[ns] 2018-10-21T11:01:59.999872 ...
# Data variables: (12/29)
#     SDN_CRUISE              |S80 b'JR18002'
#     crs                     int32 0
#     SDN_EDMO_CODE           int32 43
#     SDN_STATION             |S80 b'JR18002_MCAL_WTRD_V2_SURF'
#     SDN_LOCAL_CDI_ID        |S80 b'2021675'
#     SDN_BOT_DEPTH           (time) float32 nan nan nan nan ... nan nan nan nan
#     ...                      ...
#     TEMPHU01_SEADATANET_QC  (time) float32 nan nan nan nan ... 49.0 49.0 49.0
#     TEMPHU01                (time) float32 nan nan nan nan ... 5.584 5.585 5.597
#     TEMPSU01_SEADATANET_QC  (time) float32 nan nan nan nan ... 49.0 49.0 49.0
#     TEMPSU01                (time) float32 nan nan nan nan ... 5.552 5.553 5.563
#     TMESSG01_SEADATANET_QC  (time) float32 nan nan nan nan ... 49.0 49.0 49.0
#     TMESSG01                (time) float32 nan nan nan nan ... 6.43 6.434 6.434
# Attributes:
#     date_update:  2021-01-12T01:10:16+0000
#     comment:
#     Conventions:  SeaDataNet_1.0 CF-1.6
#     featureType:  trajectory
#     title:        SeaDataNet NETCDF TRAJECTORY Climate Forecast 1.6 - GENERAT...

# %% [markdown]
# ### df_1

# %%
df_1['SA'] = gsw.SA_from_SP(df_1['PSALSG01'].values, 0, df_1['lon'].values, df_1['lat'].values)
df_1['CT'] = gsw.CT_from_t(df_1['SA'].values, df_1['TMESSG01'].values, 0)
df_1['rho'] = gsw.rho(df_1['SA'].values, df_1['CT'].values, 0)

# %%
fig, ax = plt.subplots(figsize=(16,8))
df_plot = df_1
ax.plot(df_plot['lat'], df_plot['distance_cum']/1000, c='green')
ax.set_ylabel('Cumulative distance (km)')
ax1 = ax.twinx()
ax1.scatter(df_plot['lat'], df_plot['rho'], s=0.5, c='red')
ax1.set(xlabel='Time', ylabel='Density (kg/m3)')
ax.grid(axis='both', which='both')
ax1.yaxis.label.set_color('red')

# %% [markdown]
# ### df_2

# %%
df_2['SA'] = gsw.SA_from_SP(df_2['PSALSG01'].values, 0, df_2['lon'].values, df_2['lat'].values)
df_2['CT'] = gsw.CT_from_t(df_2['SA'].values, df_2['TMESSG01'].values, 0)
df_2['rho'] = gsw.rho(df_2['SA'].values, df_2['CT'].values, 0)

# %%
fig, ax = plt.subplots(figsize=(16,8))
df_plot = df_2
ax.plot(df_plot['lat'], df_plot['distance_cum']/1000, c='green')
ax.set_ylabel('Cumulative distance (km)')
ax1 = ax.twinx()
ax1.scatter(df_plot['lat'], df_plot['rho'], s=0.5, c='red')
ax1.set(xlabel='Time', ylabel='Density (kg/m3)')
ax.grid(axis='both', which='both')
ax1.yaxis.label.set_color('red')

# %% [markdown]
# ## Lateral density scale histogram

# %%
def sort_transect(df):
    if df['lat'][df['lat'].first_valid_index()] < df['lat'][df['lat'].last_valid_index()]:
        df = df.sort_index(ascending=False)
    return df

def downsample(df, gridsize):
    """
    Grids the data to a equally distance grid.

    Args:
        df (pd.dataframe): pandas dataframe with the North-South sorted TSG transect.
        gridsize (float): the desired distance it should be gridded to.

    Returns:
        pd.dataframe: gridded data.
    """
    from scipy.interpolate import griddata
    from datetime import datetime
    #create the distance grid
    distance_grid = np.arange(0, float(np.max(df.distance_cum)), gridsize)
    
    #we need to create a mask so the nans stay nans after gridding and are not interpolated
    df_mask = df.notna()[['rho', 'distance_cum']]
    df_mask['distance_cum'] = df['distance_cum']
    grid_mask = griddata(df_mask['distance_cum'].values, df_mask['rho'].values, distance_grid, method='linear')

    rho = griddata(df['distance_cum'].values, df['rho'].values, distance_grid, method='linear')*grid_mask
    lon = griddata(df['distance_cum'].values, df['lon'].values, distance_grid, method='linear')
    lat = griddata(df['distance_cum'].values, df['lat'].values, distance_grid, method='linear')
    time_stamp_arr = np.array([df['time'].iloc[i].to_pydatetime().timestamp() for i in range(len(df['time']))])
    time = griddata(df['distance_cum'].values, time_stamp_arr, distance_grid, method='linear')
    time = [np.datetime64(datetime.fromtimestamp(time[i])) for i in range(len(time))]
    df_aux = pd.DataFrame(rho, columns=['rho'], index=distance_grid)
    df_aux['lon'] = lon
    df_aux['lat'] = lat
    df_aux['time'] = time
    return df_aux

def method_1(df):
    g=9.8
    rho_0 = 1025
    df_500 = downsample(df,500)
    df_500['bx_500'] = (-g/rho_0)*df_500['rho'].diff()/1000
    df_500['bx_1000'] = (-g/rho_0)*df_500['bx_500'].rolling(window=2).mean()
    df_500['bx_2000'] = (-g/rho_0)*df_500['bx_500'].rolling(window=4).mean()
    df_500['bx_5000'] = (-g/rho_0)*df_500['bx_500'].rolling(window=10).mean()
    df_500['bx_10000'] = (-g/rho_0)*df_500['bx_500'].rolling(window=20).mean()
    return df_500

def method_3(df):
    g=9.8
    rho_0 = 1025
    df_500 =  downsample(df, 500)
    df_500['rho_1000'] = df_500['rho'].rolling(2).mean()
    df_500['rho_2000'] = df_500['rho'].rolling(4).mean()
    df_500['rho_5000'] = df_500['rho'].rolling(10).mean()
    df_500['rho_10000'] = df_500['rho'].rolling(20).mean()
    df_500['bx_500'] = (-g/rho_0)*df_500['rho'].diff()/1000
    df_500['bx_1000'] = (-g/rho_0)*df_500['rho_1000'].diff()/1000
    df_500['bx_2000'] = (-g/rho_0)*df_500['rho_2000'].diff()/1000
    df_500['bx_5000'] = (-g/rho_0)*df_500['rho_5000'].diff()/1000
    df_500['bx_10000'] = (-g/rho_0)*df_500['rho_10000'].diff()/1000
    return df_500

# %%
# g=9.81
# rho_0 = 1025
# dis = gsw.distance(df_1_lat['lon'].values, df_1_lat['lat'].values).mean()
# fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(12,8))
# ax0.plot(df_1_lat['rho'], df_1_lat['lat'])
# ax1.plot((-g/rho_0)*df_1_lat['rho'].diff()/dis, df_1_lat['lat'])
# ax0.plot(df_1['rho'], df_1['lat'], c='red')
# #ax1.plot(df_1['rho'].diff(), df_1['lat'])

# %%
# print(gsw.distance(df_1_lat['lon'].values, df_1_lat['lat'].values).mean())
# print(gsw.distance(df_1_lat['lon'].values, df_1_lat['lat'].values).min())
# print(gsw.distance(df_1_lat['lon'].values, df_1_lat['lat'].values).max())

# %% [markdown]
# ### df_1

# %%
# import statsmodels.api as sm
# from statsmodels.regression.rolling import RollingOLS

# %%
df_1
# Out:
#                                   lat        lon  CNDCSG01_SEADATANET_QC  \
# time
# 2018-10-28 04:00:00.000416        NaN        NaN                     NaN
# 2018-10-28 04:00:59.999936 -55.622578 -57.935474                    49.0
# 2018-10-28 04:01:59.999456 -55.624939 -57.933014                    49.0
# 2018-10-28 04:03:00.000256 -55.627316 -57.930500                    49.0
# 2018-10-28 04:03:59.999776 -55.629662 -57.927929                    49.0
# ...                               ...        ...                     ...
# 2018-10-31 00:54:59.999968 -59.587292 -55.479542                    49.0
# 2018-10-31 00:56:00.000128 -59.590004 -55.477829                    49.0
# 2018-10-31 00:56:59.999968 -59.592766 -55.476082                    49.0
# 2018-10-31 00:58:00.000128 -59.595501 -55.474312                    49.0
# 2018-10-31 00:58:59.999936 -59.598248 -55.472496                    49.0
#
#                             CNDCSG01   PSALSG01   PSALSU01  \
# time
# 2018-10-28 04:00:00.000416       NaN        NaN        NaN
# 2018-10-28 04:00:59.999936  3.348475  34.119041  34.117352
# 2018-10-28 04:01:59.999456  3.348770  34.118340  34.116650
# 2018-10-28 04:03:00.000256  3.348770  34.118042  34.116348
# 2018-10-28 04:03:59.999776  3.348630  34.118294  34.116600
# ...                              ...        ...        ...
# 2018-10-31 00:54:59.999968  2.866055  33.963066  33.958302
# 2018-10-31 00:56:00.000128  2.866180  33.965965  33.961201
# 2018-10-31 00:56:59.999968  2.866560  33.965717  33.960949
# 2018-10-31 00:58:00.000128  2.866505  33.966919  33.962151
# 2018-10-31 00:58:59.999936  2.866955  33.968819  33.964050
#
#                             TEMPHU01_SEADATANET_QC  TEMPHU01  TEMPSU01  \
# time
# 2018-10-28 04:00:00.000416                     NaN       NaN       NaN
# 2018-10-28 04:00:59.999936                    49.0   5.12715   5.11610
# 2018-10-28 04:01:59.999456                    49.0   5.12510   5.11520
# 2018-10-28 04:03:00.000256                    49.0   5.12285   5.11390
# 2018-10-28 04:03:59.999776                    49.0   5.11855   5.10995
# ...                                            ...       ...       ...
# 2018-10-31 00:54:59.999968                    49.0  -0.48920  -0.49890
# 2018-10-31 00:56:00.000128                    49.0  -0.49110  -0.49905
# 2018-10-31 00:56:59.999968                    49.0  -0.48795  -0.49680
# 2018-10-31 00:58:00.000128                    49.0  -0.48395  -0.49090
# 2018-10-31 00:58:59.999936                    49.0  -0.45095  -0.45550
#
#                             TMESSG01   distance_cum       vel         SA  \
# time
# 2018-10-28 04:00:00.000416       NaN            NaN       NaN        NaN
# 2018-10-28 04:00:59.999936   5.88935     302.579349  5.128464  34.280785
# 2018-10-28 04:01:59.999456   5.89260     607.215626  5.163327  34.280080
# 2018-10-28 04:03:00.000256   5.89205     915.016342  5.130012  34.279782
# 2018-10-28 04:03:59.999776   5.89070    1221.778379  5.199357  34.280036
# ...                              ...            ...       ...        ...
# 2018-10-31 00:54:59.999968   0.48540  494921.381002  5.398588  34.126090
# 2018-10-31 00:56:00.000128   0.48405  495238.004222  5.277054  34.129005
# 2018-10-31 00:56:59.999968   0.48860  495560.465893  5.465452  34.128758
# 2018-10-31 00:58:00.000128   0.48825  495880.497169  5.333855  34.129967
# 2018-10-31 00:58:59.999936   0.49105  496202.543527  5.458413  34.131878
#
#                                   CT          rho
# time
# 2018-10-28 04:00:00.000416       NaN          NaN
# 2018-10-28 04:00:59.999936  5.893452  1026.871941
# 2018-10-28 04:01:59.999456  5.896712  1026.870982
# 2018-10-28 04:03:00.000256  5.896165  1026.870816
# 2018-10-28 04:03:59.999776  5.894812  1026.871184
# ...                              ...          ...
# 2018-10-31 00:54:59.999968  0.489923  1027.246412
# 2018-10-31 00:56:00.000128  0.488559  1027.248826
# 2018-10-31 00:56:59.999968  0.493111  1027.248365
# 2018-10-31 00:58:00.000128  0.492755  1027.249355
# 2018-10-31 00:58:59.999936  0.495546  1027.250724
#
# [4140 rows x 15 columns]

# %%
df_sort_1 = sort_transect(df_1)

# %%
distance_cum_1 = np.insert(np.cumsum(distance_sel_1), 0, 0)
df_1['time'] = df_1.index
df_1['distance_cum'] = distance_cum_1
df_1 = df_1.set_index(df_1['distance_cum'])
df_1
# Out:
#                      lat        lon  CNDCSG01_SEADATANET_QC  CNDCSG01  \
# distance_cum
# 0.000000             NaN        NaN                     NaN       NaN
# 302.579349    -55.622578 -57.935474                    49.0  3.348475
# 607.215626    -55.624939 -57.933014                    49.0  3.348770
# 915.016342    -55.627316 -57.930500                    49.0  3.348770
# 1221.778379   -55.629662 -57.927929                    49.0  3.348630
# ...                  ...        ...                     ...       ...
# 494921.381002 -59.587292 -55.479542                    49.0  2.866055
# 495238.004222 -59.590004 -55.477829                    49.0  2.866180
# 495560.465893 -59.592766 -55.476082                    49.0  2.866560
# 495880.497169 -59.595501 -55.474312                    49.0  2.866505
# 496202.543527 -59.598248 -55.472496                    49.0  2.866955
#
#                 PSALSG01   PSALSU01  TEMPHU01_SEADATANET_QC  TEMPHU01  \
# distance_cum
# 0.000000             NaN        NaN                     NaN       NaN
# 302.579349     34.119041  34.117352                    49.0   5.12715
# 607.215626     34.118340  34.116650                    49.0   5.12510
# 915.016342     34.118042  34.116348                    49.0   5.12285
# 1221.778379    34.118294  34.116600                    49.0   5.11855
# ...                  ...        ...                     ...       ...
# 494921.381002  33.963066  33.958302                    49.0  -0.48920
# 495238.004222  33.965965  33.961201                    49.0  -0.49110
# 495560.465893  33.965717  33.960949                    49.0  -0.48795
# 495880.497169  33.966919  33.962151                    49.0  -0.48395
# 496202.543527  33.968819  33.964050                    49.0  -0.45095
#
#                TEMPSU01  TMESSG01   distance_cum       vel         SA  \
# distance_cum
# 0.000000            NaN       NaN       0.000000       NaN        NaN
# 302.579349      5.11610   5.88935     302.579349  5.128464  34.280785
# 607.215626      5.11520   5.89260     607.215626  5.163327  34.280080
# 915.016342      5.11390   5.89205     915.016342  5.130012  34.279782
# 1221.778379     5.10995   5.89070    1221.778379  5.199357  34.280036
# ...                 ...       ...            ...       ...        ...
# 494921.381002  -0.49890   0.48540  494921.381002  5.398588  34.126090
# 495238.004222  -0.49905   0.48405  495238.004222  5.277054  34.129005
# 495560.465893  -0.49680   0.48860  495560.465893  5.465452  34.128758
# 495880.497169  -0.49090   0.48825  495880.497169  5.333855  34.129967
# 496202.543527  -0.45550   0.49105  496202.543527  5.458413  34.131878
#
#                      CT          rho                       time
# distance_cum
# 0.000000            NaN          NaN 2018-10-28 04:00:00.000416
# 302.579349     5.893452  1026.871941 2018-10-28 04:00:59.999936
# 607.215626     5.896712  1026.870982 2018-10-28 04:01:59.999456
# 915.016342     5.896165  1026.870816 2018-10-28 04:03:00.000256
# 1221.778379    5.894812  1026.871184 2018-10-28 04:03:59.999776
# ...                 ...          ...                        ...
# 494921.381002  0.489923  1027.246412 2018-10-31 00:54:59.999968
# 495238.004222  0.488559  1027.248826 2018-10-31 00:56:00.000128
# 495560.465893  0.493111  1027.248365 2018-10-31 00:56:59.999968
# 495880.497169  0.492755  1027.249355 2018-10-31 00:58:00.000128
# 496202.543527  0.495546  1027.250724 2018-10-31 00:58:59.999936
#
# [4140 rows x 16 columns]

# %%
from scipy.interpolate import griddata
#create the distance grid
distance_grid = np.arange(0, float(np.max(df_1.distance_cum)), 500)

#we need to create a mask so the nans stay nans after gridding and are not interpolated
df_mask = df_1.notna()[['rho', 'distance_cum']]
df_mask['distance_cum'] = df_1['distance_cum']
grid_mask = griddata(df_mask['distance_cum'].values, df_mask['rho'].values, distance_grid, method='linear')

rho = griddata(df_1['distance_cum'].values, df_1['rho'].values, distance_grid, method='linear')*grid_mask
lon = griddata(df_1['distance_cum'].values, df_1['lon'].values, distance_grid, method='linear')
lat = griddata(df_1['distance_cum'].values, df_1['lat'].values, distance_grid, method='linear')
time_stamp_arr = np.array([df_1['time'].iloc[i].to_pydatetime().timestamp() for i in range(len(df_1['time']))])
time = griddata(df_1['distance_cum'].values, time_stamp_arr, distance_grid, method='linear')
time = [datetime.fromtimestamp(time[i]) for i in range(len(time))]
df_aux = pd.DataFrame(rho, columns=['rho'], index=distance_grid)
df_aux['lon'] = lon
df_aux['lat'] = lat
df_aux['time'] = time

# %%
df_1
# Out:
#                      lat        lon  CNDCSG01_SEADATANET_QC  CNDCSG01  \
# distance_cum
# 0.000000             NaN        NaN                     NaN       NaN
# 302.579349    -55.622578 -57.935474                    49.0  3.348475
# 607.215626    -55.624939 -57.933014                    49.0  3.348770
# 915.016342    -55.627316 -57.930500                    49.0  3.348770
# 1221.778379   -55.629662 -57.927929                    49.0  3.348630
# ...                  ...        ...                     ...       ...
# 494921.381002 -59.587292 -55.479542                    49.0  2.866055
# 495238.004222 -59.590004 -55.477829                    49.0  2.866180
# 495560.465893 -59.592766 -55.476082                    49.0  2.866560
# 495880.497169 -59.595501 -55.474312                    49.0  2.866505
# 496202.543527 -59.598248 -55.472496                    49.0  2.866955
#
#                 PSALSG01   PSALSU01  TEMPHU01_SEADATANET_QC  TEMPHU01  \
# distance_cum
# 0.000000             NaN        NaN                     NaN       NaN
# 302.579349     34.119041  34.117352                    49.0   5.12715
# 607.215626     34.118340  34.116650                    49.0   5.12510
# 915.016342     34.118042  34.116348                    49.0   5.12285
# 1221.778379    34.118294  34.116600                    49.0   5.11855
# ...                  ...        ...                     ...       ...
# 494921.381002  33.963066  33.958302                    49.0  -0.48920
# 495238.004222  33.965965  33.961201                    49.0  -0.49110
# 495560.465893  33.965717  33.960949                    49.0  -0.48795
# 495880.497169  33.966919  33.962151                    49.0  -0.48395
# 496202.543527  33.968819  33.964050                    49.0  -0.45095
#
#                TEMPSU01  TMESSG01   distance_cum       vel         SA  \
# distance_cum
# 0.000000            NaN       NaN       0.000000       NaN        NaN
# 302.579349      5.11610   5.88935     302.579349  5.128464  34.280785
# 607.215626      5.11520   5.89260     607.215626  5.163327  34.280080
# 915.016342      5.11390   5.89205     915.016342  5.130012  34.279782
# 1221.778379     5.10995   5.89070    1221.778379  5.199357  34.280036
# ...                 ...       ...            ...       ...        ...
# 494921.381002  -0.49890   0.48540  494921.381002  5.398588  34.126090
# 495238.004222  -0.49905   0.48405  495238.004222  5.277054  34.129005
# 495560.465893  -0.49680   0.48860  495560.465893  5.465452  34.128758
# 495880.497169  -0.49090   0.48825  495880.497169  5.333855  34.129967
# 496202.543527  -0.45550   0.49105  496202.543527  5.458413  34.131878
#
#                      CT          rho                       time
# distance_cum
# 0.000000            NaN          NaN 2018-10-28 04:00:00.000416
# 302.579349     5.893452  1026.871941 2018-10-28 04:00:59.999936
# 607.215626     5.896712  1026.870982 2018-10-28 04:01:59.999456
# 915.016342     5.896165  1026.870816 2018-10-28 04:03:00.000256
# 1221.778379    5.894812  1026.871184 2018-10-28 04:03:59.999776
# ...                 ...          ...                        ...
# 494921.381002  0.489923  1027.246412 2018-10-31 00:54:59.999968
# 495238.004222  0.488559  1027.248826 2018-10-31 00:56:00.000128
# 495560.465893  0.493111  1027.248365 2018-10-31 00:56:59.999968
# 495880.497169  0.492755  1027.249355 2018-10-31 00:58:00.000128
# 496202.543527  0.495546  1027.250724 2018-10-31 00:58:59.999936
#
# [4140 rows x 16 columns]

# %%
def downsample(df, gridsize):
    """
    Grids the data to a equally distance grid.

    Args:
        df (pd.dataframe): pandas dataframe with the North-South sorted TSG transect.
        gridsize (float): the desired distance it should be gridded to.

    Returns:
        pd.dataframe: gridded data.
    """
    from scipy.interpolate import griddata
    from datetime import datetime
    #create the distance grid
    distance_grid = np.arange(0, float(np.max(df.distance_cum)), gridsize)
    
    #we need to create a mask so the nans stay nans after gridding and are not interpolated
    df_mask = df.notna()[['rho', 'distance_cum']]
    df_mask['distance_cum'] = df['distance_cum']
    grid_mask = griddata(df_mask['distance_cum'].values, df_mask['rho'].values, distance_grid, method='linear')

    rho = griddata(df['distance_cum'].values, df['rho'].values, distance_grid, method='linear')*grid_mask
    lon = griddata(df['distance_cum'].values, df['lon'].values, distance_grid, method='linear')
    lat = griddata(df['distance_cum'].values, df['lat'].values, distance_grid, method='linear')
    time_stamp_arr = np.array([df['time'].iloc[i].to_pydatetime().timestamp() for i in range(len(df['time']))])
    time = griddata(df['distance_cum'].values, time_stamp_arr, distance_grid, method='linear')
    time = [np.datetime64(datetime.fromtimestamp(time[i])) for i in range(len(time))]
    df_aux = pd.DataFrame(rho, columns=['rho'], index=distance_grid)
    df_aux['lon'] = lon
    df_aux['lat'] = lat
    df_aux['time'] = time
    return df_aux

rho_0 = 1025
g = 9.81
#from GG_mthesis.d01_data.processing import downsample
df_1_500 = downsample(df_1, 500)
df_1_500 = df_1_500.drop(df_1_500[df_1_500['lat'].diff() > 0].index.values)
df_1_500['bx'] = (-g/rho_0)*df_1_500['rho'].diff()/1000

df_1_500.to_csv('data/02_intermediate/JR18002/JR18002_1', )

# %%
df_1_500['time'].iloc[0]
# Out:
# Timestamp('2018-10-28 04:00:00.000416')

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, figsize=(12,8))
ax0.plot(df_1_500.index/1000, df_1_500['rho'])
#ax1.plot((-g/rho_0)*df_1_500['rho'].diff()/dis, df_1_500['lat'])
ax1.plot(df_1_500.index/1000, df_1_500['bx'], c='red')

# %%
df_1_500
# Out:
#                   rho        lon        lat            bx
# 0.0               NaN        NaN        NaN           NaN
# 500.0     1026.871319 -57.933880 -55.624108           NaN
# 1000.0    1026.870918 -57.929788 -55.627965  3.842486e-09
# 1500.0    1026.871462 -57.925600 -55.631790 -5.203050e-09
# 2000.0    1026.872522 -57.921338 -55.635589 -1.014841e-08
# ...               ...        ...        ...           ...
# 494000.0  1027.244961 -55.484516 -59.579398  1.338137e-08
# 494500.0  1027.248087 -55.481787 -59.583677 -2.992066e-08
# 495000.0  1027.247012 -55.479116 -59.587965  1.028989e-08
# 495500.0  1027.248452 -55.476409 -59.592248 -1.378232e-08
# 496000.0  1027.249863 -55.473638 -59.596520 -1.350496e-08
#
# [992 rows x 4 columns]

# %%
def truncate(number, digits):
    import math as m
    stepper = 10 ** digits
    return m.trunc(number*stepper)/stepper

def grid_limits(df):
    if df['lat'].max() - truncate(df['lat'].max(), 2) < -0.005:
        lat_max_north = truncate(df['lat'].max(), 2)
    else:
        lat_max_north = truncate(df['lat'].max(), 2) - 0.005
        
    if df['lat'].min() - truncate(df['lat'].min(), 2) < -0.005:
        lat_max_south = truncate(df['lat'].min(), 2)
    else:
        lat_max_south = truncate(df['lat'].min(),2) + 0.005
        
    return lat_max_north, lat_max_south

def downsample_lat(df, gridsize, n_lim=-55.0, s_lim=-60.5):
    """
    Interpolates to a constant latitude grid. 

    Args:
        df (pd.dataframe): TSG data including latitude (lat), longitude (lon), density (rho) and the horizontal buoyancy gradient (bx).
        gridsize (float): latitude size in degrees.
        lat_max(float): most northern latitude.
        lat_min(float): most southern latitude.

    Returns:
        pd.dataframe: latitude gridded data. 
    """
    import math as m
    from scipy.interpolate import griddata
    #create the distance grid
    lat_max, lat_min = grid_limits(df)
    lat_grid = np.arange(int(lat_max*1000), int(lat_min*1000), int(gridsize*1000))/1000
    
    #we need to create a mask so the nans stay nans after gridding and are not interpolated
    df_mask = df.notna()[['rho', 'bx', 'lat']]
    df_mask['lat'] = df['lat']
    grid_mask = griddata(df_mask['lat'].values, df_mask['rho'].values, lat_grid, method='nearest')
    
    x = df['lat'].values
    xp = lat_grid
    rho = griddata(x, df['rho'].values, xp, method='linear')*grid_mask
    bx = griddata(x, df['bx'].values, xp, method='linear')*grid_mask
    lon = griddata(x, df['lon'].values, xp, method='linear')
    
    df_aux = pd.DataFrame(rho, columns=['rho'], index=lat_grid)
    df_aux['bx'] = pd.DataFrame(bx, columns=['bx'], index=lat_grid)
    df_aux['lon'] = pd.DataFrame(lon, columns=['lon'], index=lat_grid)
    df_aux['lat'] = lat_grid
    

    aux_north = pd.DataFrame(index=np.arange(int(n_lim*1000), int(lat_max*1000), int(gridsize*1000))/1000) 
    #this is because of floating point arithmetic, which creates small imprecisions when repeatedly adding decimal numbers (what arange does). To circumvent this issue use
    #integers when possible
    aux_north[['rho', 'bx', 'lon', 'lat']] = np.nan, np.nan, np.nan, aux_north.index

    aux_south = pd.DataFrame(index=np.arange(int(lat_min*1000), int((-60.5+gridsize)*1000), int(gridsize*1000))/1000)
    aux_south[['rho', 'bx', 'lon', 'lat']] = np.nan, np.nan, np.nan, aux_south.index    
    df_aux = pd.concat([aux_north, df_aux, aux_south])

    return df_aux

# %%
df_1_500_lat = downsample_lat(df_1_500, -0.005)
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\numpy\core\fromnumeric.py:3162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).ndim
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\numpy\core\fromnumeric.py:1970: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
gsw.distance(df_1_500_lat['lon'].values, df_1_500_lat.index.values)
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
fig, (ax0, ax1, ax2, ax3) = plt.subplots(nrows=4, figsize=(12,8))
plt.subplots_adjust(hspace=0.5)
ax0.plot(df_1_500.index, df_1_500['rho'])
#ax1.plot((-g/rho_0)*df_1_500['rho'].diff()/dis, df_1_500['lat'])
ax1.plot(df_1_500_lat.index, df_1_500_lat['rho'], c='red')
ax1.invert_xaxis()
ax2.plot(df_1_500.index/1000, df_1_500['bx'])
ax2.set_ylim([-2.5E-7, 2.5E-7])
#ax1.plot((-g/rho_0)*df_1_500['rho'].diff()/dis, df_1_500['lat'])
ax3.plot(df_1_500_lat.index, df_1_500_lat['bx'], c='red')
ax3.invert_xaxis()
ax3.set_ylim([-2.5E-7, 2.5E-7])
# Out:
# (-2.5e-07, 2.5e-07)

# %%
import cmocean.cm as cm
from matplotlib.cm import ScalarMappable

fig= plt.figure(figsize=(14,12))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-62,-52,-62,-52])
x = etopo1.x
y = etopo1.y
z = etopo1.z
vmin = z.min()
vmax = z.max()
topo_f = ax.contourf(x, y, z, 
                cmap = cm.deep_r,
                    vmin = vmin,
                    vmax = 0,
                #    norm=MidpointNormalize(
                #        midpoint=-1000,
                #        vmin=vmin,lines
                #        vmax=0
                #     ),
                levels=20
                )
plt.colorbar(ScalarMappable(norm=topo_f.norm, cmap=topo_f.cmap), pad=0.02)

# topo = ax.contour(x, y, z, 
#                   colors = 'black',
#                 #    vmin = vmin,
#                    levels=[-5500,-4500,-3000,-1500]
#                    )
#ax.clabel(topo)

ax.coastlines(zorder=100)
ax.add_feature(cartopy.feature.LAND, color='green', zorder=50)
gl = ax.gridlines(draw_labels=True, linestyle='-.', color='gray')
gl.xlabels_top = False
gl.ylabels_right = False

data = df_1_500_lat
scat = ax.scatter(data['lon'], data['lat'], c='red', s=2)
# cbar = plt.colorbar(scat, location='bottom', pad=0.05, ax=ax)
# cbar.ax.set_xticklabels(pd.to_datetime(cbar.get_ticks()).strftime(date_format='%r %d %b'), rotation=22.5)

s=4
fronts = df_front_sel
SAF = ax.plot(fronts.loc['SAF']['longitude'], fronts.loc['SAF']['latitude'],transform=ccrs.PlateCarree(), label='SAF_Park', color='purple')#, s=s)
PF = ax.plot(fronts.loc['PF']['longitude'], fronts.loc['PF']['latitude'], transform=ccrs.PlateCarree(), label='PF_Park', color='black')#, s=s)
SACCF = ax.plot(fronts.loc['SACCF']['longitude'], fronts.loc['SACCF']['latitude'],transform=ccrs.PlateCarree(), label='SACCF_Park', color='yellow')#, s=s)
NB = ax.plot(fronts.loc['NB']['longitude'], fronts.loc['NB']['latitude'],transform=ccrs.PlateCarree(), label='NB_Park', color='red')#, s=s)
SB = ax.plot(fronts.loc['SB']['longitude'], fronts.loc['SB']['latitude'],transform=ccrs.PlateCarree(), label='SB_Park', color='red')#, s=s)
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\cartopy\mpl\gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
df_1_500['rho'].diff()
# Out:
# 0.0              NaN
# 500.0            NaN
# 1000.0     -0.000401
# 1500.0      0.000544
# 2000.0      0.001060
#               ...
# 494000.0   -0.001398
# 494500.0    0.003126
# 495000.0   -0.001075
# 495500.0    0.001440
# 496000.0    0.001411
# Name: rho, Length: 992, dtype: float64

# %% [markdown]
# #### method 3

# %%
df_1_500 = method_3(df_1)

# %%
df_1_500
# Out:
#                   rho        lat     rho_1000     rho_2000     rho_5000  \
# 0.0               NaN        NaN          NaN          NaN          NaN
# 500.0     1026.871319 -55.624108          NaN          NaN          NaN
# 1000.0    1026.870918 -55.627965  1026.871119          NaN          NaN
# 1500.0    1026.871462 -55.631790  1026.871190          NaN          NaN
# 2000.0    1026.872522 -55.635589  1026.871992  1026.871555          NaN
# ...               ...        ...          ...          ...          ...
# 494000.0  1027.244961 -59.579398  1027.245660  1027.245258  1027.234916
# 494500.0  1027.248087 -59.583677  1027.246524  1027.246535  1027.238507
# 495000.0  1027.247012 -59.587965  1027.247549  1027.246605  1027.241422
# 495500.0  1027.248452 -59.592248  1027.247732  1027.247128  1027.243699
# 496000.0  1027.249863 -59.596520  1027.249157  1027.248353  1027.245443
#
#             rho_10000        bx_500       bx_1000       bx_2000       bx_5000  \
# 0.0               NaN           NaN           NaN           NaN           NaN
# 500.0             NaN           NaN           NaN           NaN           NaN
# 1000.0            NaN  3.838569e-09           NaN           NaN           NaN
# 1500.0            NaN -5.197746e-09 -6.795889e-10           NaN           NaN
# 2000.0            NaN -1.013806e-08 -7.667904e-09           NaN           NaN
# ...               ...           ...           ...           ...           ...
# 494000.0  1027.231739  1.336773e-08  8.474980e-09 -5.397123e-09 -3.113132e-08
# 494500.0  1027.231587 -2.989016e-08 -8.261211e-09 -1.220794e-08 -3.433401e-08
# 495000.0  1027.231689  1.027940e-08 -9.805379e-09 -6.651992e-10 -2.787338e-08
# 495500.0  1027.232162 -1.376827e-08 -1.744438e-09 -5.002824e-09 -2.176448e-08
# 496000.0  1027.232984 -1.349119e-08 -1.362973e-08 -1.171756e-08 -1.667970e-08
#
#               bx_10000
# 0.0                NaN
# 500.0              NaN
# 1000.0             NaN
# 1500.0             NaN
# 2000.0             NaN
# ...                ...
# 494000.0  3.551064e-09
# 494500.0  1.452278e-09
# 495000.0 -9.702218e-10
# 495500.0 -4.522975e-09
# 496000.0 -7.861039e-09
#
# [993 rows x 11 columns]

# %%
fig, (ax0, ax1, ax2, ax3, ax4) = plt.subplots(nrows=5, sharex=True, figsize=(12,8))
df = df_1_500
a = df['bx_500']
b = df['bx_1000']
c = df['bx_2000']
d = df['bx_5000']
e = df['bx_10000']
vars = [a, b, c, d, e,]
axes = [ax0, ax1, ax2, ax3, ax4]
for i in range(len(vars)):
    axes[i].plot(df['lat'], vars[i], color='black')
    axes[i].set_ylim((-3E-7,3E-7))
    axes[i].set_xlim((-55,-60.5))
    axes[i].grid()

# %%
fig, ax = plt.subplots(figsize=(12,8))
df = df_1_500
a = df['bx_500'].dropna()
b = df['bx_1000'].dropna()
c = df['bx_2000'].dropna()
d = df['bx_5000'].dropna()
e = df['bx_10000'].dropna()
aux = [a, b, c, d, e]
label = ['500 m, n = ' + str(len(a)), '1000 m, n = ' + str(len(b)), '2000 m, n = ' + str(len(c)), '5000 m, n = ' + str(len(d)), '10000 m, n = ' + str(len(e))]
colors = ['black', 'red', 'purple', 'green', 'blue', 'orange']
for i in range(len(aux)):
    ax.hist(np.log10(aux[i]), histtype='step', density=True, bins=30, label=label[i], color=colors[i])
ax.legend(loc='upper left', fontsize=8)
ax.set_xlim(-10,-6)
ax.grid(axis='x')
# ax.set_xticks([-8,-7,-6,-5,-4])
ax.set_title('JR18002a', fontsize=16)
#plt.savefig('results/analysis/25-02-22/hist_JR18002a.png', format='png')
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from scipy.stats import kstest
df = df_1_500
a = df['bx_500'].dropna()
b = df['bx_1000'].dropna()
c = df['bx_2000'].dropna()
d = df['bx_5000'].dropna()
e = df['bx_10000'].dropna()
vars_name = ['a', 'b', 'c', 'd', 'e']
vars = [a, b, c, d, e]
for i in range(len(vars)):
    print('e and ' + vars_name[i] + ': ' + str(kstest(e, vars[i])))
# Out:
# e and a: KstestResult(statistic=0.20850443893796303, pvalue=1.4432899320127035e-15)
# e and b: KstestResult(statistic=0.16722775423557934, pvalue=5.501878952429706e-10)
# e and c: KstestResult(statistic=0.11482832536075832, pvalue=7.015602171100976e-05)
# e and d: KstestResult(statistic=0.07177718997070875, pvalue=0.04183113225570567)
# e and e: KstestResult(statistic=0.0, pvalue=1.0)

# %%
df_1_500.to_csv('data/03_processed/cruises/JR18002a')

# %% [markdown]
# ### df_2

# %%
df_2
# Out:
#                                   lat        lon  CNDCSG01_SEADATANET_QC  \
# time
# 2018-11-03 05:44:00.000064        NaN        NaN                     NaN
# 2018-11-03 05:44:59.999584 -60.197357 -55.116123                    49.0
# 2018-11-03 05:46:00.000384 -60.194805 -55.117786                    49.0
# 2018-11-03 05:46:59.999872 -60.192261 -55.119408                    49.0
# 2018-11-03 05:47:59.999392 -60.189709 -55.121105                    49.0
# ...                               ...        ...                     ...
# 2018-11-06 20:55:00.001152        NaN        NaN                     NaN
# 2018-11-06 20:56:00.001952        NaN        NaN                     NaN
# 2018-11-06 20:56:59.997600        NaN        NaN                     NaN
# 2018-11-06 20:57:59.998400        NaN        NaN                     NaN
# 2018-11-06 20:58:59.999200        NaN        NaN                     NaN
#
#                             CNDCSG01   PSALSG01   PSALSU01  \
# time
# 2018-11-03 05:44:00.000064       NaN        NaN        NaN
# 2018-11-03 05:44:59.999584  2.867795  34.034393  34.026199
# 2018-11-03 05:46:00.000384  2.868385  34.037643  34.029449
# 2018-11-03 05:46:59.999872  2.868835  34.038197  34.029999
# 2018-11-03 05:47:59.999392  2.869405  34.041245  34.033051
# ...                              ...        ...        ...
# 2018-11-06 20:55:00.001152       NaN        NaN        NaN
# 2018-11-06 20:56:00.001952       NaN        NaN        NaN
# 2018-11-06 20:56:59.997600       NaN        NaN        NaN
# 2018-11-06 20:57:59.998400       NaN        NaN        NaN
# 2018-11-06 20:58:59.999200       NaN        NaN        NaN
#
#                             TEMPHU01_SEADATANET_QC  TEMPHU01  TEMPSU01  \
# time
# 2018-11-03 05:44:00.000064                     NaN       NaN       NaN
# 2018-11-03 05:44:59.999584                    49.0  -0.67990  -0.69870
# 2018-11-03 05:46:00.000384                    49.0  -0.67485  -0.69260
# 2018-11-03 05:46:59.999872                    49.0  -0.67435  -0.68975
# 2018-11-03 05:47:59.999392                    49.0  -0.67815  -0.68650
# ...                                            ...       ...       ...
# 2018-11-06 20:55:00.001152                     NaN       NaN       NaN
# 2018-11-06 20:56:00.001952                     NaN       NaN       NaN
# 2018-11-06 20:56:59.997600                     NaN       NaN       NaN
# 2018-11-06 20:57:59.998400                     NaN       NaN       NaN
# 2018-11-06 20:58:59.999200                     NaN       NaN       NaN
#
#                             TMESSG01  distance_cum       vel         SA  \
# time
# 2018-11-03 05:44:00.000064       NaN           NaN       NaN        NaN
# 2018-11-03 05:44:59.999584    0.4434    283.269549  4.801179  34.198209
# 2018-11-03 05:46:00.000384    0.4498    581.559192  4.971494  34.201473
# 2018-11-03 05:46:59.999872    0.4536    878.335580  5.030108  34.202027
# 2018-11-03 05:47:59.999392    0.4577   1177.219973  5.065837  34.205088
# ...                              ...           ...       ...        ...
# 2018-11-06 20:55:00.001152       NaN           NaN       NaN        NaN
# 2018-11-06 20:56:00.001952       NaN           NaN       NaN        NaN
# 2018-11-06 20:56:59.997600       NaN           NaN       NaN        NaN
# 2018-11-06 20:57:59.998400       NaN           NaN       NaN        NaN
# 2018-11-06 20:58:59.999200       NaN           NaN       NaN        NaN
#
#                                   CT          rho
# time
# 2018-11-03 05:44:00.000064       NaN          NaN
# 2018-11-03 05:44:59.999584  0.447568  1027.306630
# 2018-11-03 05:46:00.000384  0.453952  1027.308878
# 2018-11-03 05:46:59.999872  0.457750  1027.309103
# 2018-11-03 05:47:59.999392  0.461836  1027.311320
# ...                              ...          ...
# 2018-11-06 20:55:00.001152       NaN          NaN
# 2018-11-06 20:56:00.001952       NaN          NaN
# 2018-11-06 20:56:59.997600       NaN          NaN
# 2018-11-06 20:57:59.998400       NaN          NaN
# 2018-11-06 20:58:59.999200       NaN          NaN
#
# [5236 rows x 15 columns]

# %%
# import statsmodels.api as sm
# from statsmodels.regression.rolling import RollingOLS

# %%
distance_cum_2 = np.insert(np.cumsum(distance_sel_2), 0, 0)
df_2['time'] = df_2.index
df_2['distance_cum'] = distance_cum_2
df_2 = df_2.set_index(df_2['distance_cum'])
df_2
# Out:
#                      lat        lon  CNDCSG01_SEADATANET_QC  CNDCSG01  \
# distance_cum
# 0.000000             NaN        NaN                     NaN       NaN
# 283.269549    -60.197357 -55.116123                    49.0  2.867795
# 581.559192    -60.194805 -55.117786                    49.0  2.868385
# 878.335580    -60.192261 -55.119408                    49.0  2.868835
# 1177.219973   -60.189709 -55.121105                    49.0  2.869405
# ...                  ...        ...                     ...       ...
# 587086.833445        NaN        NaN                     NaN       NaN
# 587108.448301        NaN        NaN                     NaN       NaN
# 587131.095427        NaN        NaN                     NaN       NaN
# 587149.704107        NaN        NaN                     NaN       NaN
# 587166.365832        NaN        NaN                     NaN       NaN
#
#                 PSALSG01   PSALSU01  TEMPHU01_SEADATANET_QC  TEMPHU01  \
# distance_cum
# 0.000000             NaN        NaN                     NaN       NaN
# 283.269549     34.034393  34.026199                    49.0  -0.67990
# 581.559192     34.037643  34.029449                    49.0  -0.67485
# 878.335580     34.038197  34.029999                    49.0  -0.67435
# 1177.219973    34.041245  34.033051                    49.0  -0.67815
# ...                  ...        ...                     ...       ...
# 587086.833445        NaN        NaN                     NaN       NaN
# 587108.448301        NaN        NaN                     NaN       NaN
# 587131.095427        NaN        NaN                     NaN       NaN
# 587149.704107        NaN        NaN                     NaN       NaN
# 587166.365832        NaN        NaN                     NaN       NaN
#
#                TEMPSU01  TMESSG01   distance_cum       vel         SA  \
# distance_cum
# 0.000000            NaN       NaN       0.000000       NaN        NaN
# 283.269549     -0.69870    0.4434     283.269549  4.801179  34.198209
# 581.559192     -0.69260    0.4498     581.559192  4.971494  34.201473
# 878.335580     -0.68975    0.4536     878.335580  5.030108  34.202027
# 1177.219973    -0.68650    0.4577    1177.219973  5.065837  34.205088
# ...                 ...       ...            ...       ...        ...
# 587086.833445       NaN       NaN  587086.833445       NaN        NaN
# 587108.448301       NaN       NaN  587108.448301       NaN        NaN
# 587131.095427       NaN       NaN  587131.095427       NaN        NaN
# 587149.704107       NaN       NaN  587149.704107       NaN        NaN
# 587166.365832       NaN       NaN  587166.365832       NaN        NaN
#
#                      CT          rho                       time
# distance_cum
# 0.000000            NaN          NaN 2018-11-03 05:44:00.000064
# 283.269549     0.447568  1027.306630 2018-11-03 05:44:59.999584
# 581.559192     0.453952  1027.308878 2018-11-03 05:46:00.000384
# 878.335580     0.457750  1027.309103 2018-11-03 05:46:59.999872
# 1177.219973    0.461836  1027.311320 2018-11-03 05:47:59.999392
# ...                 ...          ...                        ...
# 587086.833445       NaN          NaN 2018-11-06 20:55:00.001152
# 587108.448301       NaN          NaN 2018-11-06 20:56:00.001952
# 587131.095427       NaN          NaN 2018-11-06 20:56:59.997600
# 587149.704107       NaN          NaN 2018-11-06 20:57:59.998400
# 587166.365832       NaN          NaN 2018-11-06 20:58:59.999200
#
# [5236 rows x 16 columns]

# %% [markdown]
# #### method 3

# %%
df_2_500 = method_3(df_2)

# %%
df_2_500
# Out:
#                   rho        lat     rho_1000     rho_2000     rho_5000  \
# 0.0               NaN        NaN          NaN          NaN          NaN
# 500.0     1027.308263 -60.195503          NaN          NaN          NaN
# 1000.0    1027.310005 -60.191222  1027.309134          NaN          NaN
# 1500.0    1027.314983 -60.186945  1027.312494          NaN          NaN
# 2000.0    1027.321344 -60.182637  1027.318163  1027.313649          NaN
# ...               ...        ...          ...          ...          ...
# 585000.0  1026.858944 -55.520149  1026.860233  1026.865400  1026.859279
# 585500.0          NaN        NaN          NaN          NaN          NaN
# 586000.0          NaN        NaN          NaN          NaN          NaN
# 586500.0          NaN        NaN          NaN          NaN          NaN
# 587000.0          NaN        NaN          NaN          NaN          NaN
#
#             rho_10000        bx_500       bx_1000       bx_2000       bx_5000  \
# 0.0               NaN           NaN           NaN           NaN           NaN
# 500.0             NaN           NaN           NaN           NaN           NaN
# 1000.0            NaN -1.665749e-08           NaN           NaN           NaN
# 1500.0            NaN -4.759344e-08 -3.212546e-08           NaN           NaN
# 2000.0            NaN -6.081371e-08 -5.420358e-08           NaN           NaN
# ...               ...           ...           ...           ...           ...
# 585000.0  1026.862688  2.464248e-08  4.337894e-08  3.235994e-08 -2.959102e-09
# 585500.0          NaN           NaN           NaN           NaN           NaN
# 586000.0          NaN           NaN           NaN           NaN           NaN
# 586500.0          NaN           NaN           NaN           NaN           NaN
# 587000.0          NaN           NaN           NaN           NaN           NaN
#
#               bx_10000
# 0.0                NaN
# 500.0              NaN
# 1000.0             NaN
# 1500.0             NaN
# 2000.0             NaN
# ...                ...
# 585000.0  7.882261e-09
# 585500.0           NaN
# 586000.0           NaN
# 586500.0           NaN
# 587000.0           NaN
#
# [1175 rows x 11 columns]

# %%
fig, (ax0, ax1, ax2, ax3, ax4) = plt.subplots(nrows=5, sharex=True, figsize=(12,8))
df = df_2_500
a = df['bx_500']
b = df['bx_1000']
c = df['bx_2000']
d = df['bx_5000']
e = df['bx_10000']
vars = [a, b, c, d, e,]
axes = [ax0, ax1, ax2, ax3, ax4]
for i in range(len(vars)):
    axes[i].plot(df['lat'], vars[i], color='black')
    axes[i].set_ylim((-3E-7,3E-7))
    axes[i].set_xlim((-55,-60.5))
    axes[i].grid(linestyle='-.')

# %%
fig, ax = plt.subplots(figsize=(12,8))
df = df_2_500
a = df['bx_500'].dropna()
b = df['bx_1000'].dropna()
c = df['bx_2000'].dropna()
d = df['bx_5000'].dropna()
e = df['bx_10000'].dropna()
aux = [a, b, c, d, e]
label = ['500 m, n = ' + str(len(a)), '1000 m, n = ' + str(len(b)), '2000 m, n = ' + str(len(c)), '5000 m, n = ' + str(len(d)), '10000 m, n = ' + str(len(e))]
colors = ['black', 'red', 'purple', 'green', 'blue', 'orange']
for i in range(len(aux)):
    ax.hist(np.log10(aux[i]), histtype='step', density=True, bins=30, label=label[i], color=colors[i])
ax.legend(loc='upper left', fontsize=8)
ax.set_xlim(-10,-6)
ax.grid(axis='x')
# ax.set_xticks([-8,-7,-6,-5,-4])
ax.set_title('JR18002b', fontsize=16)
#plt.savefig('results/analysis/25-02-22/hist_JR18002b.png', format='png')
# Out:
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\gian_\miniconda3\envs\mthesis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from scipy.stats import kstest
df = df_2_500
a = df['bx_500'].dropna()
b = df['bx_1000'].dropna()
c = df['bx_2000'].dropna()
d = df['bx_5000'].dropna()
e = df['bx_10000'].dropna()
vars_name = ['a', 'b', 'c', 'd', 'e']
vars = [a, b, c, d, e]
for i in range(len(vars)):
    print('e and ' + vars_name[i] + ': ' + str(kstest(e, vars[i])))
# Out:
# e and a: KstestResult(statistic=0.17713289182318107, pvalue=1.199040866595169e-14)
# e and b: KstestResult(statistic=0.16175186378988313, pvalue=3.1757929619402603e-12)
# e and c: KstestResult(statistic=0.13518211153250412, pvalue=1.3288136591071975e-08)
# e and d: KstestResult(statistic=0.08455409380838284, pvalue=0.00145881698325101)
# e and e: KstestResult(statistic=0.0, pvalue=1.0)

# %%
df_2_500.to_csv('data/03_processed/cruises/JR18002b')
